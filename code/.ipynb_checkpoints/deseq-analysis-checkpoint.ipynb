# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
import pickle as pkl

from pydeseq2.dds import DeseqDataSet
from pydeseq2.default_inference import DefaultInference
from pydeseq2.ds import DeseqStats
from pydeseq2.utils import load_example_data

SAVE = False  # whether to save the outputs of this notebook

if SAVE:
    # Replace this with the path to directory where you would like results to be saved
    OUTPUT_PATH = "../results/"
    os.makedirs(OUTPUT_PATH, exist_ok=True)  # Create path if it doesn't exist

# %% [markdown]
# This notebook reproduces the results from a study on chronic hypersensitivity pneumonitis. See publication here: https://pmc.ncbi.nlm.nih.gov/articles/PMC7667907/pdf/rccm.202001-0134OC.pdf

# %%
counts = pd.read_csv(f'/Users/anugulati/projects/chp-project/data/GSE150910_gene-level_count_file.csv')

# %%
counts.shape
# Out:
# (18838, 289)

# %%
counts.head()
# Out:
#      symbol  chp_26  chp_31  chp_34  chp_38  chp_1  chp_3  chp_4  chp_11  \
# 0    TSPAN6    1361     993     351     613    841    565   1093    6239
# 1      TNMD       5      13       0       0      0      6      3       4
# 2      DPM1    1929    2775    1894    2007   1436   1923   1956    4518
# 3     SCYL3     176     216     208     218    162    137    242     490
# 4  C1orf112      93     143      97     148     98    128    102     188
#
#    chp_5  ...  chp_106  chp_108  chp_109  chp_110  chp_111  chp_112  chp_113  \
# 0   1714  ...      466      638      334      349      778      872      693
# 1      0  ...        0        0        0        0        0        0        0
# 2   2411  ...      936     1162     1043      689     1006      870     1701
# 3    259  ...       57       35      122       42       73       68      145
# 4    119  ...       50       60       72       21       74       48      131
#
#    chp_114  ipf_1125  ipf_1130
# 0      465       639       944
# ...

# %%
counts.columns
# Out:
# Index(['symbol', 'chp_26', 'chp_31', 'chp_34', 'chp_38', 'chp_1', 'chp_3',
#        'chp_4', 'chp_11', 'chp_5',
#        ...
#        'chp_106', 'chp_108', 'chp_109', 'chp_110', 'chp_111', 'chp_112',
#        'chp_113', 'chp_114', 'ipf_1125', 'ipf_1130'],
#       dtype='object', length=289)

# %%
from collections import defaultdict

# %%
groups = defaultdict(int)

for sample in counts.columns:
    if sample == 'symbol': continue
    group = sample.split('_')[0]
    # print(group)
    groups[group] += 1

# %%
groups
# Out:
# defaultdict(int, {'chp': 82, 'ipf': 103, 'control': 103})

# %%
# break matrix into two matrices for chp + control and ipf + control

# %%
chp_sample_ids = []; ipf_sample_ids = []; control_sample_ids = []

for sample in counts.columns:
    group = sample.split('_')[0]
    if group == 'chp':
        chp_sample_ids.append(sample)
    elif group == 'ipf': 
        ipf_sample_ids.append(sample)
    elif group == 'control':
        control_sample_ids.append(sample)

# %%
len(chp_sample_ids)
# Out:
# 82

# %%
len(ipf_sample_ids)
# Out:
# 103

# %%
len(control_sample_ids)
# Out:
# 103

# %%
counts = counts.set_index('symbol')

# %% [markdown]
# Prepare counts matrix for DESeq2:

# %%
counts_chp_control = counts[chp_sample_ids + control_sample_ids]

# %%
counts_chp_control = counts_chp_control.T # transform into samples by genes

# %%
counts_chp_control
# Out:
# symbol        TSPAN6  TNMD  DPM1  SCYL3  C1orf112   FGR   CFH  FUCA2  GCLC  \
# chp_26          1361     5  1929    176        93  1249  8098   1477   772
# chp_31           993    13  2775    216       143  1583  8392   2292   660
# chp_34           351     0  1894    208        97  2767  3409   1547   967
# chp_38           613     0  2007    218       148  2968  5155   2286   980
# chp_1            841     0  1436    162        98  2444  3242   1737   657
# ...              ...   ...   ...    ...       ...   ...   ...    ...   ...
# control_1102     577     0  2045    213        87  5423  2294   1696   302
# control_1109     655     0  2060    158        83  1711  2424   2308   600
# control_1111    1028     5  2841    216       192  1891  6073   3587   629
# control_1112     780     0  2304    257       143  1725  7295   2400   574
# control_1113    1092     6  2084    199       114  4236  2602   1622  1153
#
# ...

# %%
counts_chp_control
# Out:
# symbol        TSPAN6  TNMD  DPM1  SCYL3  C1orf112   FGR   CFH  FUCA2  GCLC  \
# chp_26          1361     5  1929    176        93  1249  8098   1477   772
# chp_31           993    13  2775    216       143  1583  8392   2292   660
# chp_34           351     0  1894    208        97  2767  3409   1547   967
# chp_38           613     0  2007    218       148  2968  5155   2286   980
# chp_1            841     0  1436    162        98  2444  3242   1737   657
# ...              ...   ...   ...    ...       ...   ...   ...    ...   ...
# control_1102     577     0  2045    213        87  5423  2294   1696   302
# control_1109     655     0  2060    158        83  1711  2424   2308   600
# control_1111    1028     5  2841    216       192  1891  6073   3587   629
# control_1112     780     0  2304    257       143  1725  7295   2400   574
# control_1113    1092     6  2084    199       114  4236  2602   1622  1153
#
# ...

# %%
metadata_chp_control = [1] * len(chp_sample_ids) + [0] * len(control_sample_ids)

# %%
len(metadata_chp_control)
# Out:
# 185

# %%
labels = pd.Series(metadata_chp_control, index=counts_chp_control.index)

# %%
labels.name = 'label'

# %%
labels.head()
# Out:
# chp_26    1
# chp_31    1
# chp_34    1
# chp_38    1
# chp_1     1
# Name: label, dtype: int64

# %%
counts_chp_control.shape
# Out:
# (185, 18838)

# %%
chp_control_dataset = pd.concat([counts_chp_control, labels], axis=1)

# %%
chp_control_dataset.head()
# Out:
#         TSPAN6  TNMD  DPM1  SCYL3  C1orf112   FGR   CFH  FUCA2  GCLC  NFYA  \
# chp_26    1361     5  1929    176        93  1249  8098   1477   772   515
# chp_31     993    13  2775    216       143  1583  8392   2292   660   504
# chp_34     351     0  1894    208        97  2767  3409   1547   967   468
# chp_38     613     0  2007    218       148  2968  5155   2286   980   707
# chp_1      841     0  1436    162        98  2444  3242   1737   657   552
#
#         ...  AL353579.1  AC053503.7  AC012488.2  AC242842.3  AC055839.2  \
# chp_26  ...          11           0           0          14         759
# chp_31  ...          16           8           0          43         354
# chp_34  ...          11           4           0          86         202
# chp_38  ...           0           0           0          75         358
# chp_1   ...          23           0           0          80         756
#
#         AC242843.1  SPDYE17  AC022137.3  AC007244.1  label
# ...

# %%
chp_control_dataset['label'].replace(1, 'CHP',inplace=True)
chp_control_dataset['label'].replace(0, 'Control',inplace=True)

# %%
chp_control_dataset.head()
# Out:
#         TSPAN6  TNMD  DPM1  SCYL3  C1orf112   FGR   CFH  FUCA2  GCLC  NFYA  \
# chp_26    1361     5  1929    176        93  1249  8098   1477   772   515
# chp_31     993    13  2775    216       143  1583  8392   2292   660   504
# chp_34     351     0  1894    208        97  2767  3409   1547   967   468
# chp_38     613     0  2007    218       148  2968  5155   2286   980   707
# chp_1      841     0  1436    162        98  2444  3242   1737   657   552
#
#         ...  AL353579.1  AC053503.7  AC012488.2  AC242842.3  AC055839.2  \
# chp_26  ...          11           0           0          14         759
# chp_31  ...          16           8           0          43         354
# chp_34  ...          11           4           0          86         202
# chp_38  ...           0           0           0          75         358
# chp_1   ...          23           0           0          80         756
#
#         AC242843.1  SPDYE17  AC022137.3  AC007244.1  label
# ...

# %%
chp_control_dataset.tail()
# Out:
#               TSPAN6  TNMD  DPM1  SCYL3  C1orf112   FGR   CFH  FUCA2  GCLC  \
# control_1102     577     0  2045    213        87  5423  2294   1696   302
# control_1109     655     0  2060    158        83  1711  2424   2308   600
# control_1111    1028     5  2841    216       192  1891  6073   3587   629
# control_1112     780     0  2304    257       143  1725  7295   2400   574
# control_1113    1092     6  2084    199       114  4236  2602   1622  1153
#
#               NFYA  ...  AL353579.1  AC053503.7  AC012488.2  AC242842.3  \
# control_1102   732  ...           0           5           0          61
# control_1109   430  ...           7          19           0          47
# control_1111   502  ...          34          13           0          23
# control_1112   682  ...          37           0           0          41
# control_1113   557  ...          11          11          27          66
#
#               AC055839.2  AC242843.1  SPDYE17  AC022137.3  AC007244.1    label
# ...

# %%
samples = counts_chp_control.index

# %%
features = counts_chp_control.columns

# %%
from sklearn.preprocessing import StandardScaler
x = chp_control_dataset.loc[:, features].values
x = StandardScaler().fit_transform(x) # normalizing the features

# %%
x.shape
# Out:
# (185, 18838)

# %%
np.mean(x),np.std(x)
# Out:
# (np.float64(-5.746987361439593e-19), np.float64(0.9941702882582137))

# %%
normalized_chp_control = pd.DataFrame(x, columns=features, index=samples)

# %%
normalized_chp_control
# Out:
# symbol          TSPAN6      TNMD      DPM1     SCYL3  C1orf112       FGR  \
# chp_26        0.732764 -0.023622 -0.046356 -0.204975 -0.289974 -0.970210
# chp_31        0.109735  0.120843  1.237072  0.243124  0.942683 -0.830133
# chp_34       -0.977180 -0.113912 -0.099453  0.153504 -0.191362 -0.333573
# chp_38       -0.533611 -0.113912  0.071974  0.265529  1.065949 -0.249275
# chp_1        -0.147603 -0.113912 -0.794264 -0.361809 -0.166709 -0.469037
# ...                ...       ...       ...       ...       ...       ...
# control_1102 -0.594559 -0.113912  0.129622  0.209516 -0.437893  0.780332
# control_1109 -0.462504 -0.113912  0.152378 -0.406619 -0.536506 -0.776451
# control_1111  0.168990 -0.023622  1.337198  0.243124  2.150688 -0.700961
# control_1112 -0.250877 -0.113912  0.522539  0.702425  0.942683 -0.770580
# control_1113  0.277343 -0.005564  0.188787  0.052682  0.227742  0.282514
#
# symbol             CFH     FUCA2      GCLC      NFYA  ...    SPEGNB  \
# ...

# %%
from sklearn.decomposition import PCA
pca_chp = PCA(n_components=2)
principalComponents_chp = pca_chp.fit_transform(x)

# %%
principal_chp_df = pd.DataFrame(data=principalComponents_chp
             , columns = ['PC1', 'PC2'], index=samples)

# %%
principal_chp_df
# Out:
#                     PC1        PC2
# chp_26       -22.957077   2.849272
# chp_31       -27.979147 -46.178666
# chp_34       -54.597955 -63.242912
# chp_38        -5.081517 -44.374755
# chp_1        -27.322711  18.644554
# ...                 ...        ...
# control_1102 -14.319434 -33.346285
# control_1109 -40.811864 -32.209380
# control_1111  12.876690 -12.271563
# control_1112 -12.547102 -24.200371
# control_1113  -1.480081 -13.650567
#
# [185 rows x 2 columns]

# %%
print('Explained variability per principal component: {}'.format(pca_chp.explained_variance_ratio_))
# Out:
# Explained variability per principal component: [0.23787245 0.07529846]

# %%
principal_chp_df.loc[indicesToKeep, 'PC1']
# Out:
# chp_26     -22.957077
# chp_31     -27.979147
# chp_34     -54.597955
# chp_38      -5.081517
# chp_1      -27.322711
#               ...
# chp_110   -129.168626
# chp_111    -96.308883
# chp_112   -109.307545
# chp_113    -22.808247
# chp_114    -88.664189
# Name: PC1, Length: 82, dtype: float64

# %%
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('PC1',fontsize=20)
plt.ylabel('PC2',fontsize=20)
plt.title("PCA for CHP Dataset",fontsize=20)
targets = ['CHP', 'Control']
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = chp_control_dataset['label'] == target
    # print(indicesToKeep)
    plt.scatter(principal_chp_df.loc[indicesToKeep, 'PC1']
               , principal_chp_df.loc[indicesToKeep, 'PC2'], c = color, s = 50)

plt.legend(targets,prop={'size': 15})
